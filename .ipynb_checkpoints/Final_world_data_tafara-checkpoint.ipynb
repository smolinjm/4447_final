# %%
# !pip install pandas --upgrade
# Out:
# Requirement already up-to-date: pandas in ./dst1_env/lib/python3.6/site-packages (1.1.4)
# ...

# %% [markdown]
# <br><br>Tafara Makayi<br>
# Jeff Smolinski<br>
# 4447 Final Project<br>
# 11/22/2020<br>

# %%
import sys
import time
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dev_data = pd.read_csv("../data/WDIData.csv", 
                       usecols=["Country Name", "Country Code", "2015", "2016", "2017", "2018", "2019"])

# %%
dev_data.head()
# Out:
#   Country Name Country Code  2015  2016       2017  2018  2019
# 0   Arab World          ARB   NaN   NaN        NaN   NaN   NaN
# 1   Arab World          ARB   NaN   NaN        NaN   NaN   NaN
# 2   Arab World          ARB   NaN   NaN        NaN   NaN   NaN
# 3   Arab World          ARB   NaN   NaN        NaN   NaN   NaN
# 4   Arab World          ARB   NaN   NaN  37.165211   NaN   NaN

# %%
dev_data.sample(10)
# Out:
#                      Country Name Country Code          2015          2016  \
# 49983                OECD members          OED           NaN           NaN
# 1217                   Arab World          ARB  2.927475e+01  2.962057e+01
# 321402                    Somalia          SOM           NaN           NaN
# 181343                       Guam          GUM           NaN           NaN
# 65238         Upper middle income          UMC           NaN           NaN
# 268797              New Caledonia          NCL           NaN           NaN
# 30778   Latin America & Caribbean          LCN           NaN           NaN
# 339943       Syrian Arab Republic          SYR           NaN           NaN
# 290178                       Peru          PER  4.929850e+06  3.911989e+06
# 69170                     Albania          ALB           NaN           NaN
#
#             2017      2018  2019
# 49983        NaN       NaN   NaN
# 1217    30.59574  30.58612   NaN
# 321402       NaN       NaN   NaN
# ...

# %%
dev_data = pd.read_csv("../data/WDIData.csv")
dev_data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', 'Unnamed: 64'],
#       dtype='object')

# %%
dev_data_2 = dev_data[['Country Name', 'Country Code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019']]

# %%
dev_data_2.head()

# %%
dev_data[['2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019']].isnull().sum(axis = 0)
# Out:
# 2000    197464
# 2001    205430
# 2002    200587
# 2003    199975
# 2004    194667
# 2005    181871
# 2006    183183
# 2007    179192
# 2008    179823
# 2009    179848
# 2010    165264
# 2011    173425
# 2012    170540
# 2013    175479
# 2014    168885
# 2015    172946
# 2016    172544
# 2017    188819
# 2018    211316
# 2019    287023
# dtype: int64

# %%
nutrition_data = pd.read_csv("../data/ESFA.csv", 
                          usecols= ["SurveyscountryDESC","ExposurehierarchyL1DESC","PopulationGroupL2DESC", 
                                    "avg_chronic", "avg_chronic_bw", "avg_acute"])

# %%
nutrition_data[15000:15020]
# Out:
#       SurveyscountryDESC PopulationGroupL2DESC  \
# 15000            Estonia              Toddlers
# 15001            Estonia              Toddlers
# 15002            Estonia              Toddlers
# 15003            Estonia              Toddlers
# 15004            Estonia              Toddlers
# 15005            Estonia              Toddlers
# 15006            Estonia              Toddlers
# 15007            Estonia              Toddlers
# 15008            Estonia              Toddlers
# 15009            Estonia              Toddlers
# 15010            Estonia              Toddlers
# 15011            Estonia              Toddlers
# 15012            Estonia              Toddlers
# 15013            Estonia              Toddlers
# 15014            Estonia              Toddlers
# 15015            Estonia              Toddlers
# 15016            Estonia              Toddlers
# 15017            Estonia              Toddlers
# 15018            Estonia              Toddlers
# ...

# %%
nutrition_data.sample(3)

# %%
nutrition_data.columns = ['Country', 'PopulationGroupL2DESC',
       'ExposurehierarchyL1DESC', 'avg_chronic', 'avg_chronic_bw',
       'avg_acute']

# %%
nutrition_data.sample(5)
# Out:
#                Country PopulationGroupL2DESC  \
# 64651           Sweden        Other children
# 262902          France          Very elderly
# 133313          France                Adults
# 243588  Czech Republic                Adults
# 261893          France               Elderly
#
#                                   ExposurehierarchyL1DESC  avg_chronic  \
# 64651                     Grains and grain-based products    24.199669
# 262902                   Seasoning, sauces and condiments     5.375000
# 133313                    Grains and grain-based products    22.137678
# 243588  Sugar and similar, confectionery and water-bas...    39.000000
# 261893                    Grains and grain-based products    38.123476
#
#         avg_chronic_bw  avg_acute
# 64651         0.988941  70.371652
# 262902        0.074454  10.750000
# 133313        0.322110  54.557786
# 243588        0.539667  78.000000
# 261893        0.561748  95.579472

# %%
len(nutrition_data)

# %%
nutrition_data.dtypes

# %%
nutrition_data.info

# %%
#nutrition_data_country = nutrition_data.groupby('Country')
#nutrition_data_country.head(3)

# %%
len(nutrition_data[nutrition_data['Country'] == 'Spain'])

# %%
nutrition_data_group = nutrition_data.groupby(by=['Country'])
nutrition_data_group.head()
# Out:
#               Country PopulationGroupL2DESC ExposurehierarchyL1DESC  \
# 0             Austria                Adults     Alcoholic beverages
# 1             Austria                Adults     Alcoholic beverages
# 2             Austria                Adults     Alcoholic beverages
# 3             Austria                Adults     Alcoholic beverages
# 4             Austria                Adults     Alcoholic beverages
# ...               ...                   ...                     ...
# 66975  United Kingdom                Adults     Alcoholic beverages
# 66976  United Kingdom                Adults     Alcoholic beverages
# 66977  United Kingdom                Adults     Alcoholic beverages
# 66978  United Kingdom                Adults     Alcoholic beverages
# 66979  United Kingdom                Adults     Alcoholic beverages
#
#        avg_chronic  avg_chronic_bw    avg_acute
# 0       533.750000        4.741841   533.750000
# 1       647.742537        8.468373   647.742537
# ...

# %%
x = nutrition_data['PopulationGroupL2DESC'].tolist()
print(x[0:5])

# the histogram of the data
plt.figure(figsize=(12,6))
n, bins, patches = plt.hist(x,5, facecolor='b', alpha=0.75, width=0.8)


plt.xlabel('PopulationGroupL2DESC')
plt.ylabel('Counts')
plt.title('Hist PopulationGroupL2DESC')
plt.xticks(rotation=75)
plt.style.use('seaborn-whitegrid')
#plt.grid(True)
plt.show()
# Out:
# ['Adults', 'Adults', 'Adults', 'Adults', 'Adults']

# %%
#import matplotlib.colors
#cmap = plt.cm.rainbow
#norm = matplotlib.colors.Normalize(vmin=0, vmax=1200000)

x = nutrition_data['Country'].tolist()
print(x[0:5])

# the histogram of the data
plt.figure(figsize=(12,6))
n, bins, patches = plt.hist(x, 300, density=True, facecolor='b', alpha=0.75, width=0.8, )

plt.xlabel('Country')
plt.ylabel('Counts in Millions')
plt.title('Hist nutrition_data by Country Counts')
plt.xticks(rotation=78)
plt.style.use('seaborn-whitegrid')
plt.tight_layout()
#plt.grid(False)
plt.show()
# Out:
# ['Austria', 'Austria', 'Austria', 'Austria', 'Austria']

# %%
nutrition_means = nutrition_data.groupby('Country').mean()
nutrition_means
# Out:
#                 avg_chronic  avg_chronic_bw   avg_acute
# Country
# Austria           73.046957        1.195994  112.008878
# Belgium           53.438021        1.142924   93.155975
# Bulgaria          66.980027        2.090993   76.810736
# Croatia           59.993159        0.810003  126.939513
# Cyprus            45.526776        0.906919  109.515371
# Czech Republic    50.392852        1.154393   87.009075
# Denmark           25.033536        0.634072   54.192655
# Estonia           48.492113        1.274426   76.531734
# Finland           35.439645        1.045745   57.991373
# France            31.589019        0.867533   79.437501
# Germany           39.269496        1.082497   76.805758
# Greece            35.815959        1.067678  102.573951
# Hungary           44.828551        0.637715   94.842838
# Ireland           35.553160        0.481735   91.483253
# Italy             39.533670        1.296659   78.350935
# Latvia            53.326142        1.491742   92.339423
# ...

# %%
#diff.values

# %%
#nutrition_means.index.tolist()

# %%
x = nutrition_means['avg_chronic']
y = nutrition_means['avg_acute']

diff = abs(x - y)**1.8+2
diff2 = abs(x - y)/2+4

np.random.seed(19680801)
N = len(x)
colors = abs(x - y)
plt.figure(figsize=(12,6))

plt.xlabel('avg_chronic')
plt.ylabel('avg_acute')
plt.title('Scatter nutrition_means of avg_chronic by avg_acute')
plt.scatter(x, y, s=diff, c='b', alpha=0.6)

l = nutrition_means.index.tolist()

count = 0
for x,y in zip(x,y):
    
    label = f"{l[count]}"

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,diff2[count]), # distance from text to points (x,y)
                 ha='center')
    count += 1
    
plt.show()

# %%
x = nutrition_means['avg_chronic']
y = nutrition_means['avg_chronic_bw']

diff = abs(x - y)**1.8+2
diff2 = abs(x - y)/2+4

np.random.seed(19680801)
N = len(x)
colors = abs(x - y)
plt.figure(figsize=(12,6))

plt.xlabel('avg_chronic')
plt.ylabel('avg_chronic_bw')
plt.title('Scatter nutrition_means of avg_chronic by avg_chronic_bw')
plt.scatter(x, y, s=diff, c='b', alpha=0.6)

l = nutrition_means.index.tolist()

count = 0
for x,y in zip(x,y):
    
    label = f"{l[count]}"

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,diff2[count]), # distance from text to points (x,y)
                 ha='center')
    count += 1
    
plt.show()

# %%
x = nutrition_means['avg_acute']
y = nutrition_means['avg_chronic_bw']

diff = abs(x - y)**1.8+2
diff2 = abs(x - y)/2+4

np.random.seed(19680801)
N = len(x)
colors = abs(x - y)
plt.figure(figsize=(12,6))

plt.xlabel('avg_acute')
plt.ylabel('avg_chronic_bw')
plt.title('Scatter nutrition_means of avg_acute by avg_chronic_bw')
plt.scatter(x, y, s=diff, c='b', alpha=0.6)

l = nutrition_means.index.tolist()

count = 0
for x,y in zip(x,y):
    
    label = f"{l[count]}"

    plt.annotate(label, # this is the text
                 (x,y), # this is the point to label
                 textcoords="offset points", # how to position the text
                 xytext=(0,diff2[count]), # distance from text to points (x,y)
                 ha='center')
    count += 1
    
plt.show()

# %%
labels=nutrition_means.index.tolist()
sizes=nutrition_means['avg_acute'] # totals 200
z = np.zeros(len(nutrition_means))
explode = tuple(z) # tuple

fig,ax=plt.subplots(figsize=(12,6))
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('\nPie nutrition_means by Country of avg_acute\n\n')

plt.show()

# %%
nutrition_data['Country'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8f365a3520e> in <module>
# ----> 1 nutrition_data['Country'].unique()
#
# NameError: name 'nutrition_data' is not defined

# %%
nutrition_data['Country'].count()

# %%
mortality_data = pd.read_csv("../data/HNP_StatsData2.csv", skiprows=4)

# %%
mortality_data.columns = ['Country', 'Country Code', 'Indicator Name', 'Indicator Code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
mortality_data.head()

# %%
mortality_data = mortality_data[['Country', 'Country Code',
       '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020']]

# %%
mortality_data.sample(3)
# Out:
#                 Country Country Code     1960     1961     1962     1963  \
# 34064             Chile          CHL  82812.0  84553.0  86987.0  90501.0
# 80562  Papua New Guinea          PNG  18299.0  18556.0  18747.0  18923.0
# 55188         Indonesia          IDN      NaN      NaN      NaN      NaN
#
#           1964     1965      1966      1967  ...      2011      2012  \
# 34064  94730.0  98961.0  103145.0  106670.0  ...  133259.0  129981.0
# 80562  19171.0  19491.0   19833.0   20273.0  ...   63425.0   64566.0
# 55188      NaN      NaN       NaN       NaN  ...       NaN       2.7
#
#            2013      2014      2015      2016      2017      2018      2019  \
# 34064  127253.0  125097.0  123021.0  121111.0  119944.0  120035.0  120910.0
# 80562   65906.0   67240.0   68552.0   70199.0   72302.0   74679.0   77037.0
# 55188       1.1       NaN       NaN       NaN       NaN       NaN       NaN
#
#        2020
# 34064   NaN
# 80562   NaN
# 55188   NaN
#
# [3 rows x 63 columns]

# %%
mortality_data.drop(columns=['2020'], inplace=True)
mortality_data_na = mortality_data.dropna()

# %%
mortality_data_na.Country[80:110]
# Out:
# 304                Arab World
# 305                Arab World
# 306                Arab World
# 307                Arab World
# 308                Arab World
# 309                Arab World
# 310                Arab World
# 311                Arab World
# 312                Arab World
# 314                Arab World
# 315                Arab World
# 316                Arab World
# 317                Arab World
# 318                Arab World
# 360                Arab World
# 361                Arab World
# 401                Arab World
# 402                Arab World
# 418    Caribbean small states
# 419    Caribbean small states
# 420    Caribbean small states
# 642    Caribbean small states
# 643    Caribbean small states
# 644    Caribbean small states
# 645    Caribbean small states
# 646    Caribbean small states
# 647    Caribbean small states
# 648    Caribbean small states
# 649    Caribbean small states
# 650    Caribbean small states
# Name: Country, dtype: object

# %%
mort_us = mortality_data.loc[mortality_data['Country'] == 'United States']

# %%
mort_us_vals = mort_us.drop(mort_us.columns[[0,1]], axis = 1)
mort_us_vals
# Out:
#           1960    1961    1962     1963     1964     1965     1966    1967  \
# 102916  81.741  79.185  76.629  74.6802  72.7314  70.7826  68.8338  66.885
# 102917     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 102918     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 102919     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 102920     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# ...        ...     ...     ...      ...      ...      ...      ...     ...
# 103326     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 103327     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 103328     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 103329     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 103330     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
#
# ...

# %%
mort_us.columns

# %%
mort_us.values

# %%
mortality_data_na.Country

# %%
mortality_data_na_vals = mortality_data_na.drop(mortality_data_na.columns[[0,1]], axis = 1)
mortality_data_na_vals
# Out:
#                 1960          1961          1962          1963          1964  \
# 3       8.806111e+01  8.948951e+01  9.078245e+01  9.189895e+01  9.272801e+01
# 4       6.591951e+00  6.700903e+00  6.793279e+00  6.867327e+00  6.919224e+00
# 5       8.132419e+01  8.262620e+01  8.378916e+01  8.476735e+01  8.547421e+01
# 227     8.051199e+06  8.272433e+06  8.506654e+06  8.756934e+06  9.015470e+06
# 228     1.761132e+01  1.761248e+01  1.762480e+01  1.765258e+01  1.767792e+01
# ...              ...           ...           ...           ...           ...
# 107388  3.776681e+06  3.905034e+06  4.039201e+06  4.178726e+06  4.322861e+06
# 107430  3.300517e+06  3.404370e+06  3.510793e+06  3.611339e+06  3.713683e+06
# 107431  8.739200e+01  8.717900e+01  8.691800e+01  8.642200e+01  8.590800e+01
# 107471  4.761640e+05  5.006640e+05  5.284080e+05  5.673870e+05  6.091780e+05
# 107472  1.260800e+01  1.282100e+01  1.308200e+01  1.357800e+01  1.409200e+01
#
# ...

# %%
mortality_data_na_vals[['1960']]

# %%
mortality_data_na_vals.columns

# %%
sns.lineplot(data=mortality_data_na_vals, x=mortality_data_na_vals.columns, y="passengers", hue="month")

# %%
mortality_data_na

# %%
mortality_data_na_ind = mortality_data_na.set_index(['Country','Country Code'])
mortality_data_na_ind
# Out:
#                                  1960          1961          1962  \
# Country    Country Code
# Arab World ARB           8.806111e+01  8.948951e+01  9.078245e+01
#            ARB           6.591951e+00  6.700903e+00  6.793279e+00
#            ARB           8.132419e+01  8.262620e+01  8.378916e+01
#            ARB           8.051199e+06  8.272433e+06  8.506654e+06
#            ARB           1.761132e+01  1.761248e+01  1.762480e+01
# ...                               ...           ...           ...
# Zimbabwe   ZWE           3.776681e+06  3.905034e+06  4.039201e+06
#            ZWE           3.300517e+06  3.404370e+06  3.510793e+06
#            ZWE           8.739200e+01  8.717900e+01  8.691800e+01
#            ZWE           4.761640e+05  5.006640e+05  5.284080e+05
#            ZWE           1.260800e+01  1.282100e+01  1.308200e+01
#
#                                  1963          1964          1965  \
# Country    Country Code
# ...

# %%
mortality_data_na_ind_piv = pd.pivot_table(mortality_data_na_ind, columns=['Country','Country Code'])
mortality_data_na_ind_piv
# Out:
# Country        Afghanistan        Albania       Algeria American Samoa  \
# Country Code           AFG            ALB           DZA            ASM
# 1960          3.976283e+05   70904.062807  4.557970e+05         8069.2
# 1961          4.053987e+05   73160.032726  4.673396e+05         8260.8
# 1962          4.135577e+05   75438.249885  4.791678e+05         8521.2
# 1963          4.221253e+05   77705.859127  4.914396e+05         8833.6
# 1964          4.311230e+05   79976.563833  5.043739e+05         9161.6
# 1965          4.405669e+05   82206.475299  5.181455e+05         9488.8
# 1966          4.503825e+05   84409.244610  5.329693e+05         9804.8
# 1967          4.604745e+05   86652.126121  5.485908e+05        10119.2
# 1968          4.710918e+05   89114.681946  5.648483e+05        10415.6
# 1969          4.825697e+05   91686.975115  5.815050e+05        10701.2
# 1970          4.950704e+05   94037.367291  5.983901e+05        10965.2
# ...

# %%
fig, ax = plt.subplots(figsize=(12,20));
sns.lineplot(data=mortality_data_na_ind_piv, ax=ax).set_title("Mortality Rates");
ax.legend(ncol = 2, bbox_to_anchor = (1,1));
plt.xticks(rotation=80);

# %%
df = mortality_data_na_ind_piv[['United States','Canada','Brazil','Mexico','Poland','United Kingdom']]

# %%
fig, ax = plt.subplots(figsize=(16,10));
sns.lineplot(data=df, ax=ax).set_title("Mortality Rates - First World");
ax.legend(ncol = 1, bbox_to_anchor = (1,1));
plt.xticks(rotation=80);

# %%
df = mortality_data_na_ind_piv[['Haiti','Sudan','Rwanda','Senegal','Tanzania']]

# %%
fig, ax = plt.subplots(figsize=(16,10));
sns.lineplot(data=df, ax=ax).set_title("Mortality Rates - First World");
ax.legend(ncol = 1, bbox_to_anchor = (1,1));
plt.xticks(rotation=80);

# %%
mortality_data_na_ind_piv.columns[0]

# %%
l = []
for i,v in enumerate(mortality_data_na_ind_piv.loc['1960'].values):
    if v > 150:
        l.append(mortality_data_na_ind_piv.columns[i])
l
# Out:
# [('Afghanistan', 'AFG'),
#  ('Albania', 'ALB'),
#  ('Algeria', 'DZA'),
#  ('American Samoa', 'ASM'),
#  ('Andorra', 'AND'),
#  ('Angola', 'AGO'),
#  ('Antigua and Barbuda', 'ATG'),
#  ('Arab World', 'ARB'),
#  ('Argentina', 'ARG'),
#  ('Armenia', 'ARM'),
#  ('Aruba', 'ABW'),
#  ('Australia', 'AUS'),
#  ('Austria', 'AUT'),
#  ('Azerbaijan', 'AZE'),
#  ('Bahamas, The', 'BHS'),
#  ('Bahrain', 'BHR'),
#  ('Bangladesh', 'BGD'),
#  ('Barbados', 'BRB'),
#  ('Belarus', 'BLR'),
#  ('Belgium', 'BEL'),
#  ('Belize', 'BLZ'),
#  ('Benin', 'BEN'),
#  ('Bermuda', 'BMU'),
#  ('Bhutan', 'BTN'),
#  ('Bolivia', 'BOL'),
#  ('Bosnia and Herzegovina', 'BIH'),
#  ('Botswana', 'BWA'),
#  ('Brazil', 'BRA'),
#  ('British Virgin Islands', 'VGB'),
#  ('Brunei Darussalam', 'BRN'),
#  ('Bulgaria', 'BGR'),
#  ('Burkina Faso', 'BFA'),
#  ('Burundi', 'BDI'),
#  ('Cabo Verde', 'CPV'),
#  ('Cambodia', 'KHM'),
#  ('Cameroon', 'CMR'),
#  ('Canada', 'CAN'),
#  ('Caribbean small states', 'CSS'),
# ...

# %%
df = mortality_data_na_ind_piv[l]

# %%
fig, ax = plt.subplots(figsize=(16,10));
sns.lineplot(data=df, ax=ax).set_title("Mortality Rates - Declines from over 150 in 1960");
ax.legend(ncol = 1, bbox_to_anchor = (1,1));
plt.xticks(rotation=80);

# %%
df = mortality_data_na_ind_piv.loc[['1960','2019']]
df
# Out:
# Country        Afghanistan        Albania       Algeria American Samoa  \
# Country Code           AFG            ALB           DZA            ASM
# 1960          3.976283e+05   70904.062807  4.557970e+05         8069.2
# 2019          1.689187e+06  120802.009380  1.717372e+06        22144.8
#
# Country       Andorra        Angola Antigua and Barbuda    Arab World  \
# Country Code      AND           AGO                 ATG           ARB
# 1960           5384.4  2.398340e+05         2222.460098  5.644769e+06
# 2019          30876.8  1.416469e+06         3834.191332  2.619615e+07
#
# Country          Argentina        Armenia  ...    Uzbekistan       Vanuatu  \
# Country Code           ARG            ARM  ...           UZB           VUT
# 1960          8.863804e+05   82156.177704  ...  3.730777e+05   2643.532434
# 2019          1.922476e+06  125071.834675  ...  1.446823e+06  12200.190621
#
# Country      Venezuela, RB       Vietnam Virgin Islands (U.S.)  \
# ...

# %%
l = []
for column in df:
    #print(column[0])
    if (df[column]['1960'] - df[column]['2019']) < 20:
        l.append(column[0])
l
df = mortality_data_na_ind_piv[l]

# %%
fig, ax = plt.subplots(figsize=(16,10));
sns.lineplot(data=df, ax=ax).set_title("Mortality Rates - Lowest Rates of Decline 1960 - 2019");
ax.legend(ncol = 1, bbox_to_anchor = (1,1));
plt.xticks(rotation=80);

# %%
df = mortality_data_na_ind_piv.loc[['1960','2019']]
df
l = []
for column in df:
    #print(column[0])
    if (df[column]['1960'] - df[column]['2019']) > 100:
        l.append(column[0])
l
df = mortality_data_na_ind_piv[l]
df
# Out:
# Country      Bosnia and Herzegovina       Bulgaria        Croatia  \
# Country Code                    BIH            BGR            HRV
# 1960                  141627.276600  312265.135906  178021.987114
# 1961                  144284.766734  315061.965159  179079.473672
# 1962                  147017.439958  317659.792655  180230.137339
# 1963                  149729.282180  320105.299738  181356.184940
# 1964                  152310.627177  322606.739531  182410.177709
# 1965                  154696.995539  324881.306816  183504.943134
# 1966                  156885.480516  326956.684302  184697.951893
# 1967                  158876.417480  328963.752813  185824.584842
# 1968                  160762.476198  331234.562392  186926.643403
# 1969                  162650.374675  333683.467207  187996.816298
# 1970                  164591.002009  335766.572816  188853.991460
# 1971                  166507.360892  337529.895267  189593.256279
# ...

# %%
fig, ax = plt.subplots(figsize=(16,10));
sns.lineplot(data=df, ax=ax).set_title("Mortality Rates - Greatest Declines 1960 - 2019");
ax.legend(ncol = 1, bbox_to_anchor = (1,1));
plt.xticks(rotation=80);

# %%
# Iraq -.....
# Rwanda --...
# Eswatini -...-
# Haiti --..--

# %%
nutrition_datanutrition_data.sample(6)

# %%
nutrition_data

# %%
# %%script False

# %%
nutrition_means.sample(10)

# %%
#nutrition_data_group
nutrition_data_Austria = nutrition_data[nutrition_data['Country']=='Germany'].head()
nutrition_data_Austria
# Out:
#        Country PopulationGroup  \
# 28871  Germany         Infants
# 28872  Germany         Infants
# 28873  Germany         Infants
# 28874  Germany         Infants
# 28875  Germany         Infants
#
#                                  ExposurehierarchyL1DESC  avg_chronic  \
# 28871                                Alcoholic beverages     0.066667
# 28872                                Alcoholic beverages     0.048333
# 28873  Animal and vegetable fats and oils and primary...     0.202778
# 28874  Animal and vegetable fats and oils and primary...     0.419167
# 28875  Animal and vegetable fats and oils and primary...     0.877648
#
#        avg_chronic_bw  avg_acute       Diet
# 28871        0.007576   0.400000  Alcoholic
# 28872        0.005370   0.290000  Alcoholic
# 28873        0.016852   1.216667     Animal
# 28874        0.046126   2.515000     Animal
# 28875        0.094438   3.360357     Animal

# %%
#fig, ax = plt.subplots(figsize=(16,16));
'''
sns.set_theme(style="ticks")

g = sns.jointplot(
    data=nutrition_data,
    x="avg_chronic", y="avg_acute", hue="PopulationGroupL2DESC",
    kind="kde",
    #height=9
    #ax=ax
)
g.ax_marg_x.set_xlim(0, 550)
g.ax_marg_y.set_ylim(0, 500)
'''

# %%
l = nutrition_data['PopulationGroupL2DESC'].unique()
l

# %%
#nutrition_data_Sub = nutrition_data[nutrition_data['PopulationGroupL2DESC']==['Lactating women',
#      'Pregnant women']]

nutrition_data_Sub = nutrition_data.loc[nutrition_data['PopulationGroupL2DESC'] == 'Lactating women']
nutrition_data_Sub
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/tools1/dst1_env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PopulationGroupL2DESC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-221-cd09d45c3b1b> in <module>
# ...

# %%
#fig, ax = plt.subplots(figsize=(16,16));
sns.set_theme(style="ticks")

g = sns.jointplot(
    data=nutrition_data_Sub,
    x="avg_chronic", y="avg_acute", hue="PopulationGroupL2DESC",
    kind="kde",
    height=10
    #ax=ax
)
g.fig.suptitle("Nutrition Data")
g.ax_marg_x.set_xlim(0, 550)
;
g.ax_marg_y.set_ylim(0, 500)

# %%
l

# %%
l[0:6]

# %%
list(l[-2:])

# %%
list(l[-2:])

# %%
nutrition_data_sub2 = nutrition_data.loc[nutrition_data['PopulationGroupL2DESC'].isin(list(l[-2:]))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/tools1/dst1_env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PopulationGroupL2DESC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-26327499a9e3> in <module>
# ...

# %%
#fig, ax = plt.subplots(figsize=(16,16));
sns.set_theme(style="ticks")

g = sns.jointplot(
    data=nutrition_data_sub2,
    x="avg_chronic", y="avg_acute", hue="PopulationGroupL2DESC",
    kind="kde",
    height=10
    #ax=ax
)
g.fig.suptitle("Nutrition Data")
plt.legend(loc='best')
g.ax_marg_x.set_xlim(-100, 250)
g.ax_marg_y.set_ylim(-100, 570)

# %%
nutrition_data_sub3 = nutrition_data.loc[nutrition_data['PopulationGroupL2DESC'].isin(list(l[0:6]))]

# %%
#fig, ax = plt.subplots(figsize=(16,16));
sns.set_theme(style="ticks")

g = sns.jointplot(
    data=nutrition_data_sub3,
    x="avg_chronic", y="avg_acute", hue="PopulationGroupL2DESC",
    kind="kde",
    height=10
    #ax=ax
)
g.fig.suptitle("Nutrition Data")
g.ax_marg_x.set_xlim(-140, 550)
g.ax_marg_y.set_ylim(-140, 500)

# %%
nutrition_data_sub4 = nutrition_data.loc[nutrition_data['PopulationGroupL2DESC'].isin(list(l[0:4]))]

# %%
#fig, ax = plt.subplots(figsize=(16,16));
sns.set_theme(style="ticks")

g = sns.jointplot(
    data=nutrition_data_sub4,
    x="avg_chronic", y="avg_acute", hue="PopulationGroupL2DESC",
    kind="kde",
    height=10
    #ax=ax
)
g.fig.suptitle("Nutrition Data")
g.ax_marg_x.set_xlim(-140, 550)
g.ax_marg_y.set_ylim(-140, 500)

# %%
nutrition_data_sub5 = nutrition_data.loc[nutrition_data['PopulationGroupL2DESC'].isin(list(['Adults','Other children']))]

# %%
#fig, ax = plt.subplots(figsize=(16,16));
sns.set_theme(style="ticks")

g = sns.jointplot(
    data=nutrition_data_sub5,
    x="avg_chronic", y="avg_acute", hue="PopulationGroupL2DESC",
    kind="kde",
    height=10
    #ax=ax
)
g.fig.suptitle("Nutrition Data")
g.ax_marg_x.set_xlim(-140, 550)
g.ax_marg_y.set_ylim(-140, 500)

# %%
# %%script false --no-raise-error
# print(x)

# %%
sns.set_theme(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
nutrition_data

# %%
# stack

# %%
nutrition_data_stack = nutrition_data.set_index(['Country', 'PopulationGroupL2DESC']).stack()
nutrition_data_stack

# %%
nutrition_data_pop1 =nutrition_data.loc[nutrition_data['PopulationGroupL2DESC'].isin(list(['Adults','Other children']))]
nutrition_data_pop1

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=nutrition_data_pop1, kind="bar",
    x="Country", y="avg_chronic", hue="PopulationGroupL2DESC",
    ci="sd", palette="dark", alpha=.6, height=10
)
g.despine(left=True)
g.set_axis_labels("", "avg_chronic")
lw = g.ax.lines[0].get_linewidth() # lw of first line
plt.setp(g.ax.lines,linewidth=lw)
g.set_xticklabels(rotation=80)
#g.legend.set_title("PopulationGroupL2DESC - avg_chronic")
g.fig.suptitle("PopulationGroupL2DESC ~ avg_chronic")

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=nutrition_data_pop1, kind="bar",
    x="Country", y="avg_chronic", hue="PopulationGroupL2DESC",
    ci="sd", palette="dark", alpha=.6, height=10
)
g.despine(left=True)
g.set_axis_labels("", "avg_acute")
lw = g.ax.lines[0].get_linewidth() # lw of first line
plt.setp(g.ax.lines,linewidth=lw)
g.set_xticklabels(rotation=80)
#g.legend.set_title("PopulationGroupL2DESC - avg_chronic")
g.fig.suptitle("PopulationGroupL2DESC ~ avg_acute")

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=nutrition_data, kind="bar",
    x="PopulationGroupL2DESC", y="avg_chronic",
    ci="sd", palette="dark", alpha=.6, height=10
)
g.despine(left=True)
g.set_axis_labels("", "avg_chronic")
lw = g.ax.lines[0].get_linewidth() # lw of first line
plt.setp(g.ax.lines,linewidth=lw)
g.set_xticklabels(rotation=80)
#g.legend.set_title("PopulationGroupL2DESC - avg_chronic")
g.fig.suptitle("PopulationGroupL2DESC ~ avg_chronic")

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=nutrition_data, kind="bar",
    x="PopulationGroupL2DESC", y="avg_acute",
    ci="sd", palette="dark", alpha=.6, height=10
)
g.despine(left=True)
g.set_axis_labels("", "avg_acute")
lw = g.ax.lines[0].get_linewidth() # lw of first line
plt.setp(g.ax.lines,linewidth=lw)
g.set_xticklabels(rotation=80)
#g.legend.set_title("PopulationGroupL2DESC - avg_chronic")
g.fig.suptitle("PopulationGroupL2DESC ~ avg_acute")

# %%
# heatmap

# %%
sns.set_theme(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = nutrition_data
# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(.3, .5, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=1, center=0, mask=mask, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
mortality_data_na.sort_values(by=['Country'])
mortality_data_na.reset_index()

# %%
mortality_data[['1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000']]

# %%
len(mortality_data)

# %%
mortality_data.dtypes

# %%
mortality_data.info

# %%
mortality_data_short = mortality_data[["Country", "Country Code", "2015", "2016", "2017", "2018", "2019"]]

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/fips-unemp-16.csv",
                   dtype={"fips": str})

import plotly.express as px

fig = px.choropleth(df, geojson=counties, locations='fips', color='unemp',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           scope="usa",
                           labels={'unemp':'unemployment rate'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
#! pip install plotly

# %%
import plotly.express as px

df = px.data.gapminder().query("year==2007")

# %%
df

# %%
dev_data_set = dev_data.set_index(['Country Name','Country Code']).dropna()
dev_data_set
# Out:
# Empty DataFrame
# Columns: [Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, Unnamed: 64]
# Index: []
#
# [0 rows x 63 columns]

# %%
dev_data_set_country = dev_data_set.groupby('Country Code').mean()
dev_data_set_country
# Out:
# Empty DataFrame
# Columns: [1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, Unnamed: 64]
# Index: []
#
# [0 rows x 61 columns]

# %%
df_dev1 = df.merge(dev_data_set_country, left_on='iso_alpha', right_on='Country Code')
df_dev1

# %%
dev_data_group = dev_data_set.groupby(level=["Country Name","Country Code"]).mean()
dev_data_group[['2019']].sample(10)

# %%
print(df_dev1['2019'].max())
print(df_dev1['2019'].min())

# %%
fig = px.choropleth(df_dev1, locations="iso_alpha",
                    color='2019', # lifeExp is a column of gapminder
                    hover_name='country', # column to add to hover information
                    color_continuous_scale="Viridis",
                    range_color=(df_dev1['2019'].min(), df_dev1['2019'].max()))
                    #color_continuous_scale=px.colors.sequential.Viridis)
fig.update_layout(
    autosize=False,
    width=830,
    height=500,
    margin=dict(
        l=10,
        r=30,
        b=10,
        t=10,
        pad=4
    ),
    paper_bgcolor="white",
)
fig.show()

# %%
# Nutrition Group mean by Country
nutrition_means = nutrition_data.groupby('Country').mean()
# nutrition_means.columns = ['Country', 'avg_chronic', 'avg_chronic_bw', 'avg_cute']
nutrition_means
# Out:
#                 avg_chronic  avg_chronic_bw   avg_acute
# Country
# Austria           73.046957        1.195994  112.008878
# Belgium           53.438021        1.142924   93.155975
# Bulgaria          66.980027        2.090993   76.810736
# Croatia           59.993159        0.810003  126.939513
# Cyprus            45.526776        0.906919  109.515371
# Czech Republic    50.392852        1.154393   87.009075
# Denmark           25.033536        0.634072   54.192655
# Estonia           48.492113        1.274426   76.531734
# Finland           35.439645        1.045745   57.991373
# France            31.589019        0.867533   79.437501
# Germany           39.269496        1.082497   76.805758
# Greece            35.815959        1.067678  102.573951
# Hungary           44.828551        0.637715   94.842838
# Ireland           35.553160        0.481735   91.483253
# Italy             39.533670        1.296659   78.350935
# Latvia            53.326142        1.491742   92.339423
# ...

# %%
mortality_country = mortality_data_na.groupby('Country').mean()
mortality_country.columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
mortality_means = mortality_country.apply(lambda x:x.mean(), axis='columns')
mortality_means.sample(10)
# Out:
# Country
# Marshall Islands                                     5.777936e+03
# Burkina Faso                                         4.139585e+05
# Cote d'Ivoire                                        5.110737e+05
# Italy                                                2.191083e+06
# Latin America & Caribbean (excluding high income)    2.517013e+07
# Estonia                                              5.909512e+04
# Panama                                               1.010287e+05
# Cyprus                                               3.542210e+04
# Egypt, Arab Rep.                                     2.312652e+06
# British Virgin Islands                               6.981413e+03
# dtype: float64

# %%
mortality_means = pd.DataFrame(data=mortality_means, columns=['Mortality'])
mortality_means.iloc[100:110, 0:2]
# Out:
# Empty DataFrame
# Columns: [Mortality]
# Index: []

# %%
mortality_means.rename(columns={'Mortality': 'avg_mort'}, inplace=True)
mortality_means.head()
# Out:
#                     avg_mort
# Country
# Afghanistan     8.172262e+05
# Albania         1.176634e+05
# Algeria         1.030228e+06
# American Samoa  1.726604e+04
# Andorra         2.063894e+04

# %%
dev_data.rename(columns={'Country Name': 'Country'}, inplace=True)
dev_data.rename(columns={'Country Code': 'Country_Code'}, inplace=True)

# %%
dev_means = dev_data[['Country', '2015', '2016', '2017']].groupby('Country').mean()
dev_means.columns = ['dev2015','dev2016','dev2017']
dev_means
# Out:
#                          dev2015       dev2016       dev2017
# Country
# Afghanistan         2.192948e+10  2.354539e+10  2.528455e+10
# Albania             3.452896e+10  3.527469e+10  3.320936e+10
# Algeria             3.289747e+11  3.404604e+11  3.721938e+11
# American Samoa      7.941208e+07  8.039595e+07  7.865861e+07
# Andorra             9.201381e+07  9.468074e+07  1.111336e+08
# ...                          ...           ...           ...
# West Bank and Gaza  8.528464e+08  8.768546e+08  9.745894e+08
# World               3.021471e+12  3.099977e+12  3.395492e+12
# Yemen, Rep.         7.451508e+10  7.045404e+10  1.043905e+11
# Zambia              3.877552e+09  4.308872e+09  5.008476e+09
# Zimbabwe            1.151042e+09  1.199277e+09  1.315736e+09
#
# [264 rows x 3 columns]

# %%
# Begin merging dataframes: development and nutrition
temp_df = pd.merge(left=dev_means, right=nutrition_means, left_on='Country', right_on='Country').dropna()
temp_df.head()
# Out:
#                dev2015       dev2016       dev2017  avg_chronic  \
# Country
# Austria   2.217752e+10  2.308824e+10  2.659566e+10    73.046957
# Belgium   3.084668e+10  3.172698e+10  3.628466e+10    53.438021
# Bulgaria  4.619663e+09  4.793839e+09  5.519842e+09    66.980027
# Croatia   1.117263e+10  1.147340e+10  1.302834e+10    59.993159
# Cyprus    1.516563e+09  1.413071e+09  1.763295e+09    45.526776
#
#           avg_chronic_bw   avg_acute
# Country
# Austria         1.195994  112.008878
# Belgium         1.142924   93.155975
# Bulgaria        2.090993   76.810736
# Croatia         0.810003  126.939513
# Cyprus          0.906919  109.515371

# %%
# Merge resultant dataframe from above with mortality
means_df = pd.merge(left=temp_df, right=mortality_means, left_on='Country', right_on='Country').dropna()

# %%
means_df.sample(10)
# Out:
#                      dev2015       dev2016       dev2017  avg_chronic  \
# Country
# Greece          1.128499e+10  1.108004e+10  1.270446e+10          1.0
# Estonia         1.517725e+09  1.565081e+09  1.812687e+09          1.0
# Netherlands     5.343665e+10  5.351166e+10  6.193561e+10          1.0
# Austria         2.217752e+10  2.308824e+10  2.659566e+10          1.0
# France          1.405634e+11  1.434989e+11  1.583003e+11          1.0
# Slovenia        2.813269e+09  2.916334e+09  3.461243e+09          1.0
# Denmark         6.827962e+10  7.100472e+10  8.010354e+10          1.0
# Bulgaria        4.619663e+09  4.793839e+09  5.519842e+09          1.0
# Latvia          1.690127e+09  1.707798e+09  2.023266e+09          1.0
# United Kingdom  1.383189e+11  1.382822e+11  1.488633e+11          1.0
#
#                 avg_chronic_bw   avg_acute      avg_mort
# Country
# Greece                1.067678  102.573951  3.891960e+05
# Estonia               1.274426   76.531734  5.909512e+04
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.graphics.factorplots import interaction_plot

# %%
# Examine change in mortality for changes in development index
# means_df.avg_chronic = sm.add_constant(means_df.avg_chronic)

# Instantiate a gamma family model with the default link function.
gamma_model = sm.GLM(means_df.avg_mort, means_df.dev2016, family=sm.families.Gamma())
gamma_results = gamma_model.fit()
print(gamma_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               avg_mort   No. Observations:                   24
# Model:                            GLM   Df Residuals:                       23
# Model Family:                   Gamma   Df Model:                            0
# Link Function:          inverse_power   Scale:                          2.9894
# Method:                          IRLS   Log-Likelihood:                -367.30
# Date:                Sun, 22 Nov 2020   Deviance:                       104.18
# Time:                        12:03:54   Pearson chi2:                     68.8
# No. Iterations:                    10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# dev2016     1.027e-17   3.62e-18      2.833      0.005    3.17e-18    1.74e-17
# ...

# %%
# Examine change in mortality for changes in development index and chronic consumption

# means_df.avg_chronic = sm.add_constant(means_df.avg_chronic)

# Instantiate a gamma family model with the default link function.
gamma_model = sm.GLM(means_df.avg_mort, means_df.avg_acute, family=sm.families.Gamma())
gamma_results = gamma_model.fit()
print(gamma_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               avg_mort   No. Observations:                   24
# Model:                            GLM   Df Residuals:                       23
# Model Family:                   Gamma   Df Model:                            0
# Link Function:          inverse_power   Scale:                          1.1923
# Method:                          IRLS   Log-Likelihood:                -348.37
# Date:                Sun, 22 Nov 2020   Deviance:                       29.592
# Time:                        15:13:57   Pearson chi2:                     27.4
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# avg_acute   1.534e-08   3.42e-09      4.486      0.000    8.64e-09     2.2e-08
# ...

# %%
# sns.set_theme()

# Plot mortality as a function of acute consumption
g = sns.lmplot(
    data=means_df,
    x="dev2016", y="avg_mort", hue="avg_acute",
    height=5)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Development Index", "Mortality")

# %%
# Rename Columns
# nutrition_data.rename(columns={'ExposurehierarchyL1DESC': 'Diet'}, inplace=True)
nutrition_data.rename(columns={'PopulationGroupL2DESC': 'PopulationGroup'}, inplace=True)
nutrition_data.columns
# Out:
# Index(['Country', 'PopulationGroup', 'ExposurehierarchyL1DESC', 'avg_chronic',
#        'avg_chronic_bw', 'avg_acute'],
#       dtype='object')

# %%
# Extract feature from long sentence variables for Diet

import re, sys
def findFeature(row):
    regex = '^\w+'
    w = re.compile(regex)
    found = re.findall(w, row)
    if len(found)  > 0:
        return found[0]
    else:
        return None

nutrition_data['Diet'] = nutrition_data['ExposurehierarchyL1DESC'].apply(lambda x:  findFeature(x))
# nutrition_data[[''ExposurehierarchyL1DESC, 'Diet']].sample(20)

# %%
nutrition_data[['ExposurehierarchyL1DESC', 'Diet']].sample(10)
# Out:
#                                   ExposurehierarchyL1DESC        Diet
# 105377  Starchy roots or tubers and products thereof, ...     Starchy
# 23038   Fish, seafood, amphibians, reptiles and invert...        Fish
# 281085  Animal and vegetable fats and oils and primary...      Animal
# 226130  Animal and vegetable fats and oils and primary...      Animal
# 157173                    Grains and grain-based products      Grains
# 250419                              Eggs and egg products        Eggs
# 246656  Fruit and vegetable juices and nectars (includ...       Fruit
# 18427                   Vegetables and vegetable products  Vegetables
# 257589                  Vegetables and vegetable products  Vegetables
# 27999                             Milk and dairy products        Milk

# %%
diet_means = nutrition_data[['Diet', 'PopulationGroup', 'avg_chronic', 'avg_chronic_bw', 'avg_acute']].groupby(['Diet', 'PopulationGroup']).mean()

# %%
diet_means.sample(10)
# Out:
#                            avg_chronic  avg_chronic_bw   avg_acute
# Diet      PopulationGroup
# Coffee    Pregnant women    151.694939        2.160654  211.460993
# Sugar     Toddlers            8.362004        0.657251   17.708613
# Grains    Pregnant women     42.714659        0.603752   75.255398
# Legumes   Elderly            14.470635        0.198193   30.625306
# Meat      Toddlers           16.202704        1.319489   34.168514
# Eggs      Infants             6.810579        0.794646   16.029193
# Water     Infants           120.781466       15.133848  165.183533
# Composite Very elderly       71.500706        1.004416  160.066753
# Eggs      Toddlers           10.285721        0.829829   22.343432
#           Other children     14.942871        0.632414   30.530259

# %%
x = nutrition_data['Diet'].tolist()
# print(x[0:5])

# the histogram of the data
plt.figure(figsize=(18,6))
n, bins, patches = plt.hist(x,20, facecolor='b', alpha=0.75, width=0.8)

plt.xlabel('Diet')
plt.ylabel('avg_acute')
plt.title('Hist Diet')
plt.xticks(rotation=75)
plt.style.use('seaborn-whitegrid')
#plt.grid(True)
plt.show()

# %%
# Bar plot

plt.figure(figsize=(8,4))
g = sns.barplot(x='Diet', y='avg_acute', hue='avg_chronic', dodge=True, data=diet_means)
# g.set({'figure.figsize': (10,6)})

g.set_xticklabels(sorted(diet_means['Diet'].unique()), rotation=90,  horizontalalignment='right')

# %% [raw]
# diet_means.sample(10)

# %%
# Multiple Linear Regression
# Proportion of the change in mortality explained by the input variables
from sklearn.linear_model import LinearRegression

X = means_df[['dev2015', 'avg_chronic','avg_chronic_bw', 'avg_acute']]
Y = means_df['avg_mort']
model = LinearRegression().fit(X, Y)
r_sq = model.score(X, Y)

print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.12115202795042314

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Multiple Linear Regression with sklearn: predict mortality and 

# Concatenate the two variable columns into a single column
X = pd.DataFrame(np.c_[means_df['dev2016'], means_df['avg_chronic']], columns=['dev2016','avg_chronic'])
Y = means_df['avg_mort']

# Split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state=1)

mlr_model = LinearRegression()
mlr_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('Intercept: \n', mlr_model.intercept_)
print('Coefficients: \n', mlr_model.coef_)
# Out:
# Intercept:
#  657109.343703048
# Coefficients:
#  [1.23828795e-07 0.00000000e+00]

# %%
# Predict values of mortality
pred = lin_reg_mod.predict(X_test)

# Check predictions against actual values
test_set_rmse = (np.sqrt(mean_squared_error(y_test, pred)))

test_set_r2 = r2_score(y_test, pred)

# %%
test_set_rmse
# Out:
# 1188297.5134736213

# %%
prediction_error = y_test - predictions

# %%
predictions = results.predict(X_test)
prediction_error = y_test - predictions

# %%
pred = pd.DataFrame(X_test)
pred['mortality_pred'] = predictions
pred
# Out:
#          dev2016  avg_chronic  mortality_pred
# 13  2.177840e+10          1.0    1.549357e+16
# 18  1.234831e+10          1.0    8.784828e+15
# 3   1.147340e+10          1.0    8.162399e+15
# 14  1.034226e+11          1.0    7.357685e+16
# 20  2.916334e+09          1.0    2.074736e+15
# 17  6.549557e+10          1.0    4.659481e+16
# 10  1.977724e+11          1.0    1.406991e+17
# 4   1.413071e+09          1.0    1.005286e+15
